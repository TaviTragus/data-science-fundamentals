# %% [markdown]
# <a href="https://colab.research.google.com/github/TaviTragus/data-science-fundamentals/blob/main/Unit3/Tavi%20Tragus%20U3%20Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "preliz[full,notebook]"

# %%
import preliz as pz

# %% [markdown]
# # Unit 3 Exercises: Delightfully Diverse Distirbutions
#
# Use these exercises as a chance to explore the probability distributions (dists) from the pymc and preliz libraries. [Moments](https://en.wikipedia.org/wiki/Moment_(mathematics)), the main subject of these exercises, are a great way to describe dists, but there's another  way: [maximum entropy](https://en.wikipedia.org/wiki/Maximum_entropy_probability_distribution#Other_examples), which  we'll cover in a later unit.
#
# Here's what we'll cover in this Unit's exercises:
# - The first four moments: mean, variance, skew, and kurtosis, as well as the support.
# - Single variable continuous distributions.
# - Single variable discrete distriutions
#
#
# Why do we need to know this stuff? Two reasons:
# - Probability distributions are required to set priors and likelihoods in pymc.
# - Randomness and uncertainty are not well defined mathematically, but probability and probability distributions are.
#
# With that in mind, think of these exercises as an oppurtunity to explore the ways we can be uncertain, or the ways things can be random.

# %% [markdown]
# ## The First Four Moments: Mean, Variance, Skew, and Kurtosis
#
# When we talk about a probablity dist, we often care about at four things:
# - The expected value, or where a distribution is centered (mean)
# - The amount of variation from that centered value (variation)
# - Whether or not our distribution favors, leans towards, or skews towards certain values. (skew)
# - How often to expect unusually high or low values. (kurtosis)

# %% [markdown]
# ### Playing with Beta

# %% [markdown]
# **Task1**:
#
# Plot a [preliZ Beta distribution](https://preliz.readthedocs.io/en/latest/api_reference.html#preliz.distributions.beta.Beta) with $α=1$ and $β=1$.

# %%
beta = pz.Beta(alpha = 1, beta = 1)
beta.plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# **Task2**:
#
# Find the mean, variance, skew, and kurtosis of a $Beta(1,1)$ distribution. This is the same as asking for the first four moments of a $Beta(1,1)$ distribution.
#
# *Hint*: preliZ has built in function that does this for you.

# %%
beta.mean(), beta.kurtosis(), beta.var(), beta.skewness()
# Out:
# (0.5, -1.2, 0.08333333333333333, array(0.))

# %% [markdown]
# **Task3**:
#
# Plot the following distributions: $Beta(1,1)$, $Beta(0.9,0.9)$, $Beta(2,1)$, $Beta(1,2)$, $Beta(7,11)$, $Beta(96,42)$, $Beta(5,5)$, $Beta(500,500)$, $Beta(0.8,0.9)$.
#
# Then, determine which of those distribtuions has:
# - the largest/smallest mean
# - the largest/smallest variance
# - the largest/smallest skew
# - the largest/smallest kurtosis

# %%
beta1 = pz.Beta(alpha = 1, beta = 1)
beta1.plot_pdf()
beta1.mean(), beta1.kurtosis(), beta1.var(), beta1.skewness()
# Out:
# (0.5, -1.2, 0.08333333333333333, array(0.))

# %%
beta2 = pz.Beta(alpha = .9, beta = .9)
beta2.plot_pdf()
beta2.mean(), beta2.kurtosis(), beta2.var(), beta2.skewness()
# Out:
# (0.5, -1.2500000000000002, 0.0892857142857143, array(0.))

# %%
beta3 = pz.Beta(alpha = 2, beta = 1)
beta3.plot_pdf()
beta3.mean(), beta3.kurtosis(), beta3.var(), beta3.skewness()
# Out:
# (0.6666666666666666, -0.6, 0.05555555555555555, -0.565685424949238)

# %%
beta4 = pz.Beta(alpha = 1, beta = 2)
beta4.plot_pdf()
beta4.mean(), beta4.kurtosis(), beta4.var(), beta4.skewness()
# Out:
# (0.3333333333333333, -0.6, 0.05555555555555555, 0.565685424949238)

# %%
beta5 = pz.Beta(alpha = 7, beta = 11)
beta5.plot_pdf()
beta5.mean(), beta5.kurtosis(), beta5.var(), beta5.skewness()
# Out:
# (0.3888888888888889,
#  -0.22931354359925787,
#  0.012508122157244964,
#  0.1986970545340808)

# %%
beta6 = pz.Beta(alpha = 96, beta = 42)
beta6.plot_pdf()
beta6.mean(), beta6.kurtosis(), beta6.var(), beta6.skewness()
# Out:
# (0.6956521739130435,
#  -0.011997937472861485,
#  0.0015231670995906488,
#  -0.14323292412687752)

# %%
beta7 = pz.Beta(alpha = 5, beta = 5)
beta7.plot_pdf()
beta7.mean(), beta7.kurtosis(), beta7.var(), beta7.skewness()
# Out:
# (0.5, -0.46153846153846156, 0.022727272727272728, array(0.))

# %%
beta8 = pz.Beta(alpha = 500, beta = 500)
beta8.plot_pdf()
beta8.mean(), beta8.kurtosis(), beta8.var(), beta8.skewness()
# Out:
# (0.5, -0.005982053838484547, 0.00024975024975024975, array(0.))

# %%
beta9 = pz.Beta(alpha = .8, beta = .9)
beta9.plot_pdf()
beta9.mean(), beta9.kurtosis(), beta9.var(), beta9.skewness()
# Out:
# (0.47058823529411764,
#  -1.263657274295572,
#  0.09227220299884659,
#  0.1046752255731734)

# %%
beta1.kurtosis(), beta2.kurtosis(), beta3.kurtosis(), beta4.kurtosis(), beta5.kurtosis(), beta6.kurtosis(), beta7.kurtosis(), beta8.kurtosis(), beta9.kurtosis()
# Out:
# (-1.2,
#  -1.2500000000000002,
#  -0.6,
#  -0.6,
#  -0.22931354359925787,
#  -0.011997937472861485,
#  -0.46153846153846156,
#  -0.005982053838484547,
#  -1.263657274295572)

# %% [markdown]
# ### Mean:
#
# *   Largest is beta6 (mean ~ .69), alpha = 96 beta = 42
# *   Smallest is beta4 (mean ~ .33), alpha = 1 beta = 2
#
# ### Variance:
#
# *   Largest is beta9 (variance ~ .092), alpha = .8 beta = .9
# *   Smallest is beta8 (variance ~ .00025), alpha = 500 beta = 500
#
# ### Skew:
#
# *   Largest is beta4 (skew ~ .57), alpha = 1 beta = 2
# *   Smallest is beta3 (skew ~ -.57), alpha = 2 beta = 1
#
# ### Kurtosis:
#
# *   Largest is beta8 (kurtosis ~ 0.060), alpha = 500 beta = 500
# *   Smallest is beta9 (kurtosis ~ -1.2), alpha = .8 beta = .9

# %% [markdown]
# ###Playing with other Continuous Distributions
#
# For the remaining tasks, make sure to continue to use the [preliZ documentation](https://preliz.readthedocs.io/en/latest/api_reference.html).
#
# The [wikipedia pages for each of the probability distributions](https://en.wikipedia.org/wiki/List_of_probability_distributions) are also great resources.
#
# [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/probability/probability-distributions) is another great resource as well.

# %% [markdown]
# **Task4**:
#
# Plot the pdfs of each of the following distributions: $Normal(μ=0,σ=1)$, $StudentT(ν=1,μ=0,σ=1)$, $Exponential(λ=1/2)$, $Gamma(α=2,β=1)$, $HalfStudentT(ν=1,σ1)$
#
# For the T distribution, use
#
# ```
# support=(-4,4)
# ```
# inside the plot_pdf function.

# %%
pz.Normal(mu = 0, sigma = 1).plot_pdf(support = (-4, 4))
pz.StudentT(nu = 1, mu = 0, sigma = 1).plot_pdf(support = (-4, 4))
pz.Exponential(lam = .5).plot_pdf(support = (-4, 4))
pz.Gamma(alpha = 2, beta = 1).plot_pdf(support = (-4, 4))
pz.HalfStudentT(nu = 1, sigma = 1).plot_pdf(support = (-4, 4))
# Out:
# /usr/local/lib/python3.10/dist-packages/numba/np/ufunc/dufunc.py:287: RuntimeWarning: divide by zero encountered in nb_logpdf
#   return super().__call__(*args, **kws)
# <Axes: >

# %%
pz.HalfStudentT(nu = 1, sigma = 1).plot_pdf()
# Out:
# <Axes: >

# %% [markdown]
# **Task5**:
#
# What x values do the Exponenital, Gamma, HalfSutdentT, and HalfNormal functions support? What x values do the Normal and T distribution support? What x values does the Beta distribution support?

# %% [markdown]
# Exponential,
# Gamma,
# HalfStudentT,
# HalfNormal [0, infinity)
#
#
# Normal,
# StudentT (-infinity, infinity)
#
# Beta [0, 1]

# %% [markdown]
# **Task6**:
#
# Can a distribution with support $[0,∞]$ have negative (or left) skew? If so, plot that specific distribution.

# %%
#yes_it_can #weibull_distribution
weibull = pz.Weibull(alpha = 19, beta = 3)
weibull.plot_pdf()
weibull.skewness()
# Out:
# -0.8549534595663317

# %% [markdown]
# **Task7**:
#
# Name a distribution that supports the real numbers with variance equal to 1, 0 skew, and 0 kurtosis.

# %%
norm = pz.Normal(mu = 15, sigma = 1)
norm.plot_pdf()
norm.var(), norm.skewness(), norm.kurtosis()
# Out:
# (1.0, 0, 0)

# %% [markdown]
# A normal distribution where sigma = 1.

# %% [markdown]
# **Task8**:
#
# Name a distribution with support $(-∞,∞)$ and that has negative skew.

# %%
emg = pz.ExGaussian(mu = 3, sigma = 5,nu = -1)
emg.plot_pdf()
emg.skewness()
# Out:
# -0.015085856549091082

# %% [markdown]
# Exponentially modified guassian distribution with negative nu.

# %% [markdown]
# ###Playing with Discrete Distributions

# %% [markdown]
# **Task9**:
#
# Plot the pdfs (techincally the pmfs) of the following distributions: $Bernoulli(p=0.7)$, $Binomial(n=10,p=0.7)$, $Poisson(λ=7)$, $Geometric(p=0.7)$, $HyperGeometric(N=50,k=35,n=15)$, $Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])$
#
# Additionally, compute the first four moments for all those distributions--except the Categorical distribution.

# %%
ber = pz.Bernoulli(p = .7)
ber.plot_pdf()
bin = pz.Binomial(n = 10, p = .7)
bin.plot_pdf()
poi = pz.Poisson(mu = 7)
poi.plot_pdf()
geo = pz.Geometric(p = .7)
geo.plot_pdf()
hpg = pz.HyperGeometric(N = 50, k = 35, n = 15)
hpg.plot_pdf()
cat = pz.Categorical(p=[0.05,0.3,0.05,0.1,0.2,0.4])
cat.plot_pdf()
# Out:
# <Axes: >

# %%
ber.mean(), ber.var(), ber.skewness(), ber.kurtosis()
# Out:
# (0.7, 0.21000000000000002, -0.8728715609439692, -1.238095238095238)

# %%
bin.mean(), bin.var(), bin.skewness(), bin.kurtosis()
# Out:
# (7.0, 2.1000000000000005, -0.27602622373694163, -0.12380952380952379)

# %%
poi.mean(), poi.var(), poi.skewness(), poi.kurtosis()
# Out:
# (7.0, 7.0, 0.3779644730092272, 0.14285714285714285)

# %%
geo.mean(), geo.var(), geo.skewness(), geo.kurtosis()
# Out:
# (1.4285714285714286, 0.6122448979591838, 2.3734644158557194, 7.633333333333333)

# %%
hpg.mean(), hpg.var(), hpg.skewness(), hpg.kurtosis()
# Out:
# (10.5, 2.25, -0.1111111111111111, -0.08983451536643026)

# %% [markdown]
# **Task10**:
#
# Describe what processes "generate" each of the previous discrete distributions models. Also report their support.
#
# Here's a spicier way to phrase the question: describe these distributions' maximum entropy conditions in english.
#
# Hint: Make sure to read any of the: preliZ documentation, relevant wikipedia articles, or wolfram alpha.

# %% [markdown]
# The Bernoulli distribution describes the probability of successes (x=1) and failures (x=0).
#
# The Binomial distribution is a discrete probability distribution of the number of successes in a sequence of n independent yes/no experiments, each of which yields success with probability p.
#
# The Poisson distribution is often used to model the number of events occurring in a fixed period of time when the times at which events occur are independent.
#
# The Geometric distribution is the probability that the first success in a sequence of Bernoulli trials occurs on the x’th trial.
#
# The HyperGeometric distribution is the probability of $x$ successes in a sequence of $n$ bernoulli trials taken without replacement from a population of $N$ objects, containing $k$ good (or successful or Type I) objects.
#
# The Categorical distribution is the most general discrete distribution. Models the probability of getting one of the integers that are the indices of the array of the probability.
